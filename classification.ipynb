# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import datetime
from sklearn.model_selection import train_test_split

df= pd.read_csv("./mushroooms.csv")
df
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
"""as i can see i have too much unknowns in the stalk root feature, i can
fill them,but for now ill drop them"""
#df[df['stalk-root']=='?']
df.drop(columns=['stalk-root'])
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 3984     e         x           y         b       t    n               f
# 4023     p         x           y         e       f    y               f
# 4076     e         f           y         u       f    n               f
# 4100     p         x           y         e       f    y               f
# 4104     p         x           y         n       f    f               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
"""lets turn the data to numeric so we can work with something"""
for col in df.columns:
    df[col]=np.numeric(df[col])
df
# plt.figure(figsize=(20,10))
# df.corr()
#sns.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-9d122617e70a> in <module>
#       1 """lets turn the data to numeric so we can work with something"""
#       2 for col in df.columns:
# ----> 3     df[col]=np.numeric(df[col])
#       4 df
#       5 # plt.figure(figsize=(20,10))
#
# c:\users\talso\desktop\aiex\final project\venv\lib\site-packages\numpy\__init__.py in __getattr__(attr)
#     212                 return Tester
#     213             else:
# --> 214                 raise AttributeError("module {!r} has no attribute "
#     215                                      "{!r}".format(__name__, attr))
#     216
#
# AttributeError: module 'numpy' has no attribute 'numeric'

# %%
sns.barplot(x='cap-shape',y='class',data=df,alpha=0.05,color='b')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-2e72b79be31b> in <module>
# ----> 1 sns.barplot(x='cap-shape',y='class',data=df,alpha=0.05,color='b')
#       2
#
# c:\users\talso\desktop\aiex\final project\venv\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\users\talso\desktop\aiex\final project\venv\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3177 ):
#    3178
# -> 3179     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
# ...
